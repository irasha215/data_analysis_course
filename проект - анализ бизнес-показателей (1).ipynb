# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-и-подготовка-данных-к-анализу" data-toc-modified-id="Загрузка-и-подготовка-данных-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка и подготовка данных к анализу</a></span><ul class="toc-item"><li><span><a href="#Visits" data-toc-modified-id="Visits-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Visits</a></span></li><li><span><a href="#Orders" data-toc-modified-id="Orders-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Orders</a></span></li><li><span><a href="#Costs" data-toc-modified-id="Costs-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Costs</a></span></li><li><span><a href="#Описание-данных:" data-toc-modified-id="Описание-данных:-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Описание данных:</a></span><ul class="toc-item"><li><span><a href="#Visits" data-toc-modified-id="Visits-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Visits</a></span></li><li><span><a href="#Orders" data-toc-modified-id="Orders-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Orders</a></span></li><li><span><a href="#Costs" data-toc-modified-id="Costs-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Costs</a></span></li></ul></li></ul></li><li><span><a href="#Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Создание-пользовательских-профилей" data-toc-modified-id="Создание-пользовательских-профилей-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Создание пользовательских профилей</a></span></li><li><span><a href="#Распределение-пользователей-по-странам" data-toc-modified-id="Распределение-пользователей-по-странам-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Распределение пользователей по странам</a></span></li><li><span><a href="#Распределение-пользователей-по-устройствам" data-toc-modified-id="Распределение-пользователей-по-устройствам-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Распределение пользователей по устройствам</a></span></li><li><span><a href="#Распределение-пользователей-по-рекламным-источникам" data-toc-modified-id="Распределение-пользователей-по-рекламным-источникам-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Распределение пользователей по рекламным источникам</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Расходы-на-маркетинг" data-toc-modified-id="Расходы-на-маркетинг-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Расходы на маркетинг</a></span><ul class="toc-item"><li><span><a href="#Распределение-трат-по-источникам" data-toc-modified-id="Распределение-трат-по-источникам-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Распределение трат по источникам</a></span></li><li><span><a href="#Изменение-метрик-во-времени" data-toc-modified-id="Изменение-метрик-во-времени-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Изменение метрик во времени</a></span></li></ul></li><li><span><a href="#Средняя-стоимость-привлечения-одного-пользователя" data-toc-modified-id="Средняя-стоимость-привлечения-одного-пользователя-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Средняя стоимость привлечения одного пользователя</a></span></li></ul></li><li><span><a href="#Оценка-окупаемости-рекламы-для-привлечения-пользователей" data-toc-modified-id="Оценка-окупаемости-рекламы-для-привлечения-пользователей-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оценка окупаемости рекламы для привлечения пользователей</a></span><ul class="toc-item"><li><span><a href="#Проанализируйте-общую-окупаемость-рекламы" data-toc-modified-id="Проанализируйте-общую-окупаемость-рекламы-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Проанализируйте общую окупаемость рекламы</a></span></li><li><span><a href="#Проанализируйте-окупаемость-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Проанализируйте-окупаемость-рекламы-с-разбивкой-по-устройствам-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Проанализируйте окупаемость рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Проанализируйте-окупаемость-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Проанализируйте-окупаемость-рекламы-с-разбивкой-по-странам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Проанализируйте окупаемость рекламы с разбивкой по странам</a></span></li><li><span><a href="#Проанализируйте-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Проанализируйте-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Графики-конверсии-и-удержания" data-toc-modified-id="Графики-конверсии-и-удержания-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Графики конверсии и удержания</a></span><ul class="toc-item"><li><span><a href="#Конверсия-и-удержание-по-устройствам" data-toc-modified-id="Конверсия-и-удержание-по-устройствам-5.5.1"><span class="toc-item-num">5.5.1&nbsp;&nbsp;</span>Конверсия и удержание по устройствам</a></span></li><li><span><a href="#Конверсия-и-удержание-по-странам" data-toc-modified-id="Конверсия-и-удержание-по-странам-5.5.2"><span class="toc-item-num">5.5.2&nbsp;&nbsp;</span>Конверсия и удержание по странам</a></span></li><li><span><a href="#Конверсия-и-удержания-по-рекламным-каналам" data-toc-modified-id="Конверсия-и-удержания-по-рекламным-каналам-5.5.3"><span class="toc-item-num">5.5.3&nbsp;&nbsp;</span>Конверсия и удержания по рекламным каналам</a></span></li></ul></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# # Проект: Анализ бизнес-показателей
#
#
# Вы - маркетинговый аналитик развлекательного приложения Procrastinate Pro+. Несколько прошлых месяцев ваш бизнес постоянно нес убытки - в привлечение пользователей была вложена куча денег, а толку никакого. Вам нужно разобраться в причинах этой ситуации.

# %% [markdown]
# ## Загрузка и подготовка данных к анализу

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from datetime import datetime, timedelta
import numpy as np

# %%
try:
    visits = pd.read_csv('/Users/irinasaahmetova/Documents/ЯП_projects/анализ бизнес-показателей/visits_info_short.csv')
    orders = pd.read_csv('/Users/irinasaahmetova/Documents/ЯП_projects/анализ бизнес-показателей/orders_info_short.csv')
    costs = pd.read_csv('/Users/irinasaahmetova/Documents/ЯП_projects/анализ бизнес-показателей/costs_info_short.csv')
    
except:
    visits = pd.read_csv('/datasets/visits_info_short.csv')
    orders = pd.read_csv('/datasets/orders_info_short.csv')
    costs = pd.read_csv('/datasets/costs_info_short.csv')

# %% [markdown]
# ### Visits

# %%
visits.head()
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %% [markdown]
# Переименуем столбцы:

# %%
visits.columns = visits.columns.str.lower().str.replace(' ', '_')

# %% [markdown]
# Изменим тип данных:

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])

# %% [markdown]
# Пропусков в данных нет, проверим на наличие дубликатов:

# %%
visits.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Orders

# %%
orders.head()
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %%
# Переименуем названия столбцов
orders.columns = orders.columns.str.lower().str.replace(' ', '_')

# Изменим тип данных
orders['event_dt'] = pd.to_datetime(orders['event_dt'])

# Проверим на наличие дубликатов
orders.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Costs

# %%
costs.head()
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %%
# Переименуем названия столбцов
costs.columns = costs.columns.str.lower().str.replace(' ', '_')

# Изменим тип данных
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# Проверим на наличие дубликатов
costs.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ---

# %% [markdown]
# ### Описание данных:

# %% [markdown]
# #### Visits

# %% [markdown]
#  Хранит лог сервера с информацией о посещениях сайта
#
#  - **user_id** — уникальный идентификатор пользователя,
#  - **region** — страна пользователя,
#  - **device** — тип устройства пользователя,
#  - **channel** — идентификатор источника перехода,
#  - **session_start** — дата и время начала сессии,
#  - **Session_end** — дата и время окончания сессии.

# %% [markdown]
# #### Orders

# %% [markdown]
#  Хранит информацию о покупках
#
#  - **user_id** — уникальный идентификатор пользователя,
#  - **event_dt** — дата и время покупки,
#  - **revenue** — сумма заказа.

# %% [markdown]
# #### Costs

# %% [markdown]
#  Хранит информацию о расходах на рекламу
#
#  - **channel* — идентификатор рекламного источника,
#  - **dt** — дата проведения рекламной кампании,
#  - **costs** — расходы на эту кампанию.
#
#  ---

# %% [markdown]
# ## Функции для расчета и анализа LTV, ROI, удержания и конверсии

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # определяем дату первого посещения и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # добавляем флаги для всех событий из event_names
    #for event in event_names:
        #if event in events['event_name'].unique():
            #profiles[event] = profiles['user_id'].isin(
            #    events.query('event_name == @event')['user_id'].unique()
            #)

    # считаем количество уникальных пользователей с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %%
# Функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    dimensions = ['payer'] + dimensions

    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')


    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days


    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result


    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)


    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )


    
    return result_raw, result_grouped, result_in_time

# %%
# Функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')


    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )


    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )


    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days


    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    if 'cohort' in dimensions: 
        dimensions = []

    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return result_raw, result_grouped, result_in_time

# %%
# Функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        result = result.fillna(0).cumsum(axis=1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes


        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        roi = result.div(cac['cac'], axis=0)

        roi = roi[~roi['cohort_size'].isin([np.inf])]

        roi['cohort_size'] = cohort_sizes

        roi['cac'] = cac['cac']


        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        return result, roi

    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    if 'cohort' in dimensions:
        dimensions = []

    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  
        result_grouped,  
        result_in_time, 
        roi_grouped, 
        roi_in_time,  
    )

# %%
# Функция для сглаживания фрейма

def filter_data(df, window):
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Создание пользовательских профилей

# %%
users = get_profiles(visits, orders, costs)
users.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %% [markdown]
# Определяем минимальную и максимальную даты привлечения пользователей:

# %%
first_user = min(users['first_ts'])
first_user
# Out:
# Timestamp('2019-05-01 00:00:41')

# %%
last_user = max(users['first_ts'])
last_user
# Out:
# Timestamp('2019-10-27 23:59:04')

# %% [markdown]
# ### Распределение пользователей по странам

# %%
users.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %%
# Создадим таблицу с группировкой по регионам
users_by_region = users.groupby('region').agg({'user_id' : 'nunique', 'payer' : ['sum', 'mean']})

# Переименуем столбцы
users_by_region.columns = ['Количество пользователей', 'Количество платящих пользователей', '% платящих пользователей']
users_by_region.index = users_by_region.index.rename('Страна')

# Изменим формат для отображения процентов
users_by_region = users_by_region.sort_values(by='Количество пользователей', ascending=False).style.format({'% платящих пользователей' : '{:.2%}'})
users_by_region
# Out:
# <style type="text/css">
# </style>
# <table id="T_35449_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Количество пользователей</th>
#       <th class="col_heading level0 col1" >Количество платящих пользователей</th>
#       <th class="col_heading level0 col2" >% платящих пользователей</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Страна</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35449_level0_row0" class="row_heading level0 row0" >United States</th>
#       <td id="T_35449_row0_col0" class="data row0 col0" >100002</td>
#       <td id="T_35449_row0_col1" class="data row0 col1" >6902</td>
#       <td id="T_35449_row0_col2" class="data row0 col2" >6.90%</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# **Вывод:** Как видно по таблице, наибольшая доля платящий пользователей приходится на США.

# %% [markdown]
# ### Распределение пользователей по устройствам

# %%
users_by_device = users.groupby('device').agg({'user_id' : 'nunique', 'payer' : ['sum', 'mean']})
users_by_device.columns = ['Пользователи', 'Платящие пользователи', '% платящих пользователей']
users_by_device.index = users_by_device.index.rename('Устройство')

users_by_device = users_by_device.sort_values(by='Пользователи', ascending = False).style.format({'% платящих пользователей' : '{:.2%}'})
users_by_device
# Out:
# <style type="text/css">
# </style>
# <table id="T_dc6a7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Пользователи</th>
#       <th class="col_heading level0 col1" >Платящие пользователи</th>
#       <th class="col_heading level0 col2" >% платящих пользователей</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Устройство</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc6a7_level0_row0" class="row_heading level0 row0" >iPhone</th>
#       <td id="T_dc6a7_row0_col0" class="data row0 col0" >54479</td>
#       <td id="T_dc6a7_row0_col1" class="data row0 col1" >3382</td>
#       <td id="T_dc6a7_row0_col2" class="data row0 col2" >6.21%</td>
#     </tr>
#     <tr>
#       <th id="T_dc6a7_level0_row1" class="row_heading level0 row1" >Android</th>
# ...

# %% [markdown]
# **Вывод:** Больше всего пользователи заходят в приложение с iPhone, однако наибольший процент оплат происходит с Mac. В целом, можно сказать, что пользователи Apple имеют лучшую конверсию в покупателей, возможно в этом есть плюсы ApplePay.

# %% [markdown]
# ### Распределение пользователей по рекламным источникам

# %%
users_by_channel = users.groupby('channel').agg({'user_id' : 'nunique', 'payer' : ['sum', 'mean']})
users_by_channel.columns = ['Пользователи', 'Платящие пользователи', '% платящих пользователей']
users_by_channel.index = users_by_channel.index.rename('Источник привлечения')

users_by_channel.sort_values(by='Пользователи', ascending = False).style.format({'% платящих пользователей' : '{:.2%}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_80a9c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Пользователи</th>
#       <th class="col_heading level0 col1" >Платящие пользователи</th>
#       <th class="col_heading level0 col2" >% платящих пользователей</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Источник привлечения</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80a9c_level0_row0" class="row_heading level0 row0" >organic</th>
#       <td id="T_80a9c_row0_col0" class="data row0 col0" >56439</td>
#       <td id="T_80a9c_row0_col1" class="data row0 col1" >1160</td>
#       <td id="T_80a9c_row0_col2" class="data row0 col2" >2.06%</td>
#     </tr>
#     <tr>
# ...

# %%
# Отсортируем таблицу по доле платящих пользователей
users_by_channel.sort_values(by='% платящих пользователей', ascending = False).style.format({'% платящих пользователей' : '{:.2%}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_9964c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Пользователи</th>
#       <th class="col_heading level0 col1" >Платящие пользователи</th>
#       <th class="col_heading level0 col2" >% платящих пользователей</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Источник привлечения</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9964c_level0_row0" class="row_heading level0 row0" >FaceBoom</th>
#       <td id="T_9964c_row0_col0" class="data row0 col0" >29144</td>
#       <td id="T_9964c_row0_col1" class="data row0 col1" >3557</td>
#       <td id="T_9964c_row0_col2" class="data row0 col2" >12.20%</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# **Вывод:** Наибольшее количество пользователей нашло приложение органически, однако среди них наблюдается наименьший процент оплат. Наибольшая доля платящих пользователей пришли из FaceBoom и AdNonSense.

# %% [markdown]
# ## Маркетинг

# %% [markdown]
# ### Расходы на маркетинг

# %%
costs.head()
# Out:
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %%
sum_costs = costs['costs'].sum()
print('Общая сумма расходов на маркетинг = ', '{:.2f}'.format(sum_costs))
# Out:
# Общая сумма расходов на маркетинг =  105497.30

# %% [markdown]
# #### Распределение трат по источникам

# %%
costs.groupby('channel').agg({'costs' : 'sum'}).sort_values(by = 'costs', ascending=False)
# Out:
#                        costs
# channel
# TipTop              54751.30
# FaceBoom            32445.60
# WahooNetBanner       5151.00
# AdNonSense           3911.25
# OppleCreativeMedia   2151.25
# RocketSuperAds       1833.00
# LeapBob              1797.60
# lambdaMediaAds       1557.60
# MediaTornado          954.48
# YRabbit               944.22

# %% [markdown]
# #### Изменение метрик во времени

# %%
(
    costs
    .pivot_table(index = 'dt', columns = 'channel', values = 'costs', aggfunc = 'sum')
    .plot(figsize=(15, 10))
)

plt.title('Динамика стоимости привлечения пользователей')
plt.show()

# %%
costs['month'] = costs['dt'].astype('datetime64[M]')

(
    costs
    .pivot_table(index = 'month', columns = 'channel', values = 'costs', aggfunc = 'sum')
    .plot(figsize=(15, 10))
)

plt.title('Динамика стоимости привлечения пользователей по месяцам')
plt.show()

# %% [markdown]
# **Вывод:** Как видно на графике, расходы на маркетинг постоянно увеличиваются, наиболее это заметно по рекламам на сервисах TipTop и FaceBoom

# %% [markdown]
# ### Средняя стоимость привлечения одного пользователя

# %%
users.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %%
print('Средняя стоимость привлечения одного пользователя для проекта:', '{:.2f}'.format(users['acquisition_cost'].mean()))
# Out:
# Средняя стоимость привлечения одного пользователя для проекта: 0.70

# %% [markdown]
# Рассмотрим среднюю стоимость привлечения одного пользователя для каждого источника:

# %%
(
    users
    .groupby('channel')
    .agg({'acquisition_cost' : 'mean'})
    .sort_values(by='acquisition_cost', ascending=False)
    .rename(columns = {'acquisition_cost' : 'mean_acquisition_cost'})
)
# Out:
#                     mean_acquisition_cost
# channel
# TipTop                           2.799003
# FaceBoom                         1.113286
# AdNonSense                       1.008054
# lambdaMediaAds                   0.724802
# WahooNetBanner                   0.602245
# RocketSuperAds                   0.412095
# OppleCreativeMedia               0.250000
# YRabbit                          0.218975
# MediaTornado                     0.218717
# LeapBob                          0.210172
# organic                          0.000000

# %% [markdown]
# Рассмотрим динамику изменения средней стоимости привлечения одного пользователя по месяцам:

# %%
(
    users
    .pivot_table(index = 'month', columns = 'channel', values = 'acquisition_cost', aggfunc = 'mean')
    .plot(grid=True, figsize = (15,10))
)

plt.title('Динамика средней стоимости привлечения одного пользователя по месяцам')
plt.show()

# %% [markdown]
# **Вывод:** Средняя стоимость привлечения одного пользователя для всего проекта составляет примерно 70 центов. Наибольшие расходы на трафик от сервисов TipTop, FaceBoom и AdNonSense. По таблице в пункте 3.4 можно сделать предварительный вывод, что наибольшее количество пользователей действительно приходят от FaceBoom и TipTop, однако они не всегда конвертируются в платящих.

# %% [markdown]
# ## Оценка окупаемости рекламы для привлечения пользователей

# %% [markdown]
# ### Проанализируйте общую окупаемость рекламы

# %% [markdown]
# Для начала исключим пользователей, которые перешли в приложение органически. Они не нужны для выявления окупаемости рекламы.

# %%
users = users.query('channel != "organic"')

# %%
users.head()
# Out:
#     user_id            first_ts     channel   device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom      Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom   iPhone  United States
# 3  22593348 2019-08-22 21:35:48  AdNonSense       PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit   iPhone  United States
# 7  46006712 2019-06-30 03:46:29  AdNonSense  Android         France
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769
# 7  2019-06-30 2019-06-01   True          1.008000

# %%
# Зададим дату исследования и горизонт анализа
max_date = datetime(2019, 11, 1)
horizon = 14

# %%
# Вызовем функцию get_ltv для поиска LTV и ROI
users['dt'] = pd.to_datetime(users['dt'])
ltv_raw, ltv, ltv_history, roi, roi_history =  get_ltv(users, orders, max_date, horizon, dimensions=[])

# %% [markdown]
# Рассмотрим тепловую карту LTV без разбивки:

# %%
plt.figure(figsize = (16,5))
sns.heatmap(ltv.drop(columns=['cohort_size']), annot=True, fmt='.2f')
plt.title('Тепловая карта LTV без разбивки')
plt.xlabel('Лайфтайм')
plt.show()

# %% [markdown]
# LTV пользователей, впервые воспользовавшихся приложением с мая до ноября 2019 года, составляет 90 центов.

# %%
# Вызовем функцию для построения графиков:
plot_ltv_roi(ltv, ltv_history, roi, roi_history, 14)

# %% [markdown]
# **Вывод:**
#
#  - Медианное значение LTV пользователей на 14 день составляет примерно 90 центов, что превышает среднюю стоимость привлечения пользователей(70 центов)
#  - Реклама для приложения не окупается
#  - Окупаемость постоянно падает.

# %% [markdown]
# ### Проанализируйте окупаемость рекламы с разбивкой по устройствам

# %%
ltv_raw, ltv, ltv_history, roi, roi_history =  get_ltv(users, orders, max_date, horizon, dimensions=['device'])

# %%
plot_ltv_roi(ltv, ltv_history, roi, roi_history, 14)

# %% [markdown]
# **Вывод:**
#
#  - LTV пользователей с разных устройств практически одинаковое
#  - Стоимость привлечения пользователей PC намного ниже, чем для других устройств, скорее всего с этим связана более высокая окупаемость рекламы для этих пользователей
#  - Реклама окупается для пользователей, заходящих в приложение с PC, наименьшая окупаемость среди пользователей iPhone.
#  - Однако стоит отметить, что ROI для пользователей PC пересекает границу только к 11 дню, а разница с другими устройствами не очень большая. Таким образом, можно сделать вывод, что устройство, с которого заходят пользователи, не играет большой роли для окупаемости рекламы.

# %% [markdown]
# ### Проанализируйте окупаемость рекламы с разбивкой по странам

# %%
ltv_raw, ltv, ltv_history, roi, roi_history =  get_ltv(users, orders, max_date, horizon, dimensions=['region'])

# %%
plt.figure(figsize = (16,5))
sns.heatmap(ltv.drop(columns=['cohort_size']), annot=True, fmt='.2f')
plt.title('Тепловая карта LTV по странам')
plt.xlabel('Лайфтайм')
plt.show()

# %%
plt.figure(figsize = (16,5))
sns.heatmap(roi.drop(columns=['cohort_size']), annot=True, fmt='.2f')
plt.title('Тепловая карта ROI по странам')
plt.xlabel('Лайфтайм')
plt.show()

# %%
plot_ltv_roi(ltv, ltv_history, roi, roi_history, 14)

# %% [markdown]
# **Вывод:**
#
#  - Наибольший LTV среди пользователей из США, он достигает 1 доллар на 14 день пользования
#  - Однако стоиомость привлечения пользователей в США превышает LTV, из-за чего реклама там не окупается.
#  - США - единственный регион, в котором реклама стабильно не окупается(за исключением 1 дня лайфтайма). Пользователей из этого региона значительно больше, чем из других, скорее всего именно из-за этого реклама приложения стабильно не окупается.

# %% [markdown]
# ### Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам

# %%
ltv_raw, ltv, ltv_history, roi, roi_history =  get_ltv(users, orders, max_date, horizon, dimensions=['channel'])

# %%
plt.figure(figsize = (16,5))
sns.heatmap(ltv.drop(columns=['cohort_size']), annot=True, fmt='.2f')
plt.title('Тепловая карта LTV по каналам привлечения')
plt.xlabel('Лайфтайм')
plt.show()

# %%
plt.figure(figsize = (16,5))
sns.heatmap(roi.drop(columns=['cohort_size']), annot=True, fmt='.2f')
plt.title('Тепловая карта ROI по каналам привлечения')
plt.xlabel('Лайфтайм')
plt.show()

# %%
plot_ltv_roi(ltv, ltv_history, roi, roi_history, 14)

# %%
users.groupby(['channel', 'region']).agg({'user_id' : 'nunique'}).sort_values(by='user_id', ascending=False)
# Out:
#                                   user_id
# channel            region
# FaceBoom           United States    29144
# TipTop             United States    19561
# RocketSuperAds     United States     4448
# MediaTornado       United States     4364
# YRabbit            United States     4312
# OppleCreativeMedia UK                3052
# LeapBob            UK                3046
# WahooNetBanner     UK                3003
# OppleCreativeMedia France            2991
# LeapBob            France            2988
# WahooNetBanner     France            2971
#                    Germany           2579
# OppleCreativeMedia Germany           2562
# LeapBob            Germany           2519
# AdNonSense         France            1366
#                    UK                1295
#                    Germany           1219
# lambdaMediaAds     UK                 758
#                    France             742
#                    Germany            649

# %% [markdown]
# **Вывод:**
#
#  - Лидеры по LTV - рекламные сети LambdaMediaAds и TipTop
#  - Реклама от LambdaMediaAds окупается на 230 процентов к 14 дню, также у нее высокий показатель LTV. Однако по этому каналу приходит наименьшее количество пользователей.
#  - Самая высокая стоимость привлечения пользователей через рекламу от TipTop
#  - Не окупается реклама от TipTop, FaceBoom и AdNonSense.
#  - И TipTop и FaceBoom являются лидерами по привличению пользователей, а также привлекают пользователей только из США, однако стоит заметить, что и там, и там реклама окупается только на первый день лайфтайма.
#  - Именно из-за этих рекламных кампаний(TipTop и FaceBoom) не окупается реклама приложения в целом.

# %% [markdown]
# ### Графики конверсии и удержания

# %% [markdown]
# #### Конверсия и удержание по устройствам

# %%
# Вызовем функцию get_conversion для расчета конверсии
conversion_raw, conversion, conversion_history = get_conversion(users, orders, max_date, horizon, dimensions = ['device'])

# %%
# Вызовем функцию plot_conversion для ее визуализации
plot_conversion(conversion, conversion_history, horizon)

# %%
plt.figure(figsize=(15, 6))
sns.heatmap(conversion.drop(columns=['cohort_size', 0]), annot=True, fmt='.2%')
plt.title('Тепловая карта конверсии')
plt.show()

# %%
# Вызовем функцию get_retention для расчета удержания
retention_raw, retention, retention_history = get_retention(users, visits, max_date, horizon, dimensions = ['device'])

# %%
# Вызовем функцию plot_retention для его визуализации
plot_retention(retention, retention_history, horizon)

# %%
plt.figure(figsize=(15, 6))
sns.heatmap(retention.drop(columns=['cohort_size', 0]), annot=True, fmt='.2%')
plt.title('Тепловая карта удержания')
plt.show()

# %% [markdown]
# **Вывод:**
#
#  - Наибольший процент удержания наблюдается среди пользователей PC, однако они неохотно переходят в категорию платящих
#  - Наибольшая конверсия выделяется среди пользователей техники Apple.

# %% [markdown]
# #### Конверсия и удержание по странам

# %%
conversion_raw, conversion, conversion_history = get_conversion(users, orders, max_date, horizon, dimensions = ['region'])
plot_conversion(conversion, conversion_history, horizon)

# %%
retention_raw, retention, retention_history = get_retention(users, visits, max_date, horizon, dimensions = ['region'])
plot_retention(retention, retention_history, horizon)

# %% [markdown]
# **Вывод:**
#
#  - Наибольшая конверсия выделяется среди пользователей из США, однако среди них же наблюдается наименьшее удержание. Таким образом, компании стоит обратить внимание на удержание пользователей из этого региона, это позволит значительно увеличить прибыль

# %% [markdown]
# #### Конверсия и удержания по рекламным каналам

# %%
conversion_raw, conversion, conversion_history = get_conversion(users, orders, max_date, horizon, dimensions = ['channel'])
plot_conversion(conversion, conversion_history, horizon)

# %%
retention_raw, retention, retention_history = get_retention(users, visits, max_date, horizon, dimensions = ['channel'])
plot_retention(retention, retention_history, horizon)

# %% [markdown]
# **Вывод:**
#
#  - Наибольшая конверсия наблюдается среди пользователей, перешедших в приложение через FaceBoom, AdNonSense и LambdaMediaAds
#  - Среди пользователей от FaceBoom и AdNonSense выделяется критически низкий уровень удержания. Стоит отметить, что это лидеры среди рекламных каналов по привлечению пользователей.
#  - У траффика от TipTop средняя конверсия и уровень удержания, однако данная рекламная компания не окупается.

# %% [markdown]
# ## Вывод

# %% [markdown]
# **Причины неэффективности привлечения пользователей:**
#
#  - Основная проблема наблюдается среди пользователей из США. Среди привлеченных пользователей наибольшее количество пользователей из этого региона, среди них также отмечается высокий уровень конверсии, однако у них критически низкий уровень удержания. Таким образом, пользователи приложения не успевают превратиться в платящих, из-за чего рекламные кампании не окупаются.
#  - Наименьшее ударжание наблюдается у пользователей, пришедших в приложение через рекламные каналы FaceBoom и AdNonSense. Стоит учитывать, что FaceBoom является лидером по количеству привлеченных пользователей.
#  - Также одним из лидеров по привлечению пользователей является TipTop, однако несмотря на высокий LTV данная реклама не окупается. Скорее всего это происходит из-за очень высокой средней стоимости привлечения пользователя, она больше, чем у других рекламных каналов, практически в 3 раза.
#  - Таким образом, рекламный бюджет не окупается в основном из-за таких рекламных компаний как FaceBoom и TipTop, которые направляют траффик только из США и являются лидерами по привличенным пользователям.

# %% [markdown]
# **Вывод:**
#
#  - Стоит обратить внимание на пользователей из США, определить, почему среди них наблюдается такое низкое удержание.
#  - Также стоит обратить внимание на отдельные рекламные каналы(FaceBoom и AdNonSense), возможно именно из-за рекламной подачи среди этих пользователей такое низкое удержание
#  - Возможно стоит увеличить траффик по другим рекламным каналам. Например, LamndaMediaAds: высокая конверсия, реклама окупается 2 раза, однако меньше всего пользователей.
